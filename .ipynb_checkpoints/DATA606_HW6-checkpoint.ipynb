# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import arviz as az
from sklearn.linear_model import LogisticRegression
import pymc3 as pm

# %% [markdown]
# ## The Dataset
#
# You can download the dataset from here: https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database

# %%
## 1 point
diab_df = pd.read_csv('diabetes.csv')
diab_df.head()
## ToDo: read the csv file into a dataframe and show the first 5 rows
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
## 3 points
y = diab_df["Outcome"]
x = diab_df.loc[:, diab_df.columns != "Outcome"]
clf = LogisticRegression(solver='lbfgs', max_iter=10000).fit(x, y)
print('Intercept:', clf.intercept_)
print('Coefficient:', clf.coef_)
## Assign the Outcome variable to y and the rest to X.
## USe LogisticRegression to fit the data and print out the intercept and the coefficients
# Out:
# Intercept: [-8.3644866]
# Coefficient: [[ 1.22504795e-01  3.51112854e-02 -1.32989843e-02  7.79015138e-04
#   -1.17339258e-03  8.96471193e-02  8.67318608e-01  1.49732914e-02]]

# %%
## 2 points

## Explain what the code is doing:
## What are the prior probabilities of the intercept and coefficients?
# Which likelihood distribution has been used?
## What does pm.invlogit(linreg) mean?
## What is map_est?

with pm.Model() as logreg_model:
  
    w0 = pm.Normal('w0', mu=0, sd=100)
    w1 = pm.Normal('w1', mu=0, sd=100)
    w2 = pm.Normal('w2', mu=0, sd=100)
    w3 = pm.Normal('w3', mu=0, sd=100)
    w4 = pm.Normal('w4', mu=0, sd=100)
    w5 = pm.Normal('w5', mu=0, sd=100)
    w6 = pm.Normal('w6', mu=0, sd=100)
    w7 = pm.Normal('w7', mu=0, sd=100)
    w8 = pm.Normal('w8', mu=0, sd=100)
   
    
    linreg = w0 * np.ones(diab_df.shape[0]) + w1 * diab_df.Pregnancies.values + w2 * diab_df.Glucose.values \
    + w3 * diab_df.BloodPressure.values + w4 * diab_df.SkinThickness.values + w5 * diab_df.Insulin.values + \
    w6 * diab_df.BMI.values + w7 * diab_df.DiabetesPedigreeFunction.values + w8 * diab_df.Age.values
    p_outcome = pm.invlogit(linreg)

    likelihood = pm.Bernoulli('likelihood', p_outcome, observed=diab_df.Outcome.values)

    
    map_est= pm.find_MAP()
    print(map_est)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='135' class='' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [135/135 00:00<00:00 logp = -411.44, ||grad|| = 12.242]
#     </div>
# {'w0': array(-8.40381811), 'w1': array(0.12319259), 'w2': array(0.03516101), 'w3': array(-0.01329351), 'w4': array(0.00062072), 'w5': array(-0.00119151), 'w6': array(0.08968112), 'w7': array(0.94539065), 'w8': array(0.0148632)}

# %% [markdown]
# ### Answer
# 1. The code gave the coefficient in the model and came up with the maximum likelihood to implement the logistic regression
# 2. The prior probabilities of the intercept and coefficients are w0, w1, w2, w3, w4, w5, w6, w7, w8.
# 3. It is Bernoulli distribution.
# 4. pm.invlogit(linreg) indicates that the sigmod function of linereg is 1/(1+exp(-x)).
# 5. map_est finds the maximum a-posteriori estimate for the vector of logistic regression weights.

# %%
## 2 points

with logreg_model:
## ToDo: draw 400 samples using pm.Metropolis() and assign to the variable trace
  trace = pm.sample(400, step=pm.Metropolis())
## Explain the output of the plot 
az.plot_posterior(trace)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#
# Only 400 samples in chain.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [w8]
# >Metropolis: [w7]
# >Metropolis: [w6]
# >Metropolis: [w5]
# >Metropolis: [w4]
# >Metropolis: [w3]
# >Metropolis: [w2]
# >Metropolis: [w1]
# >Metropolis: [w0]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1400' class='' max='1400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1400/1400 00:06<00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1400' class='' max='1400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1400/1400 00:17<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 400 draw iterations (2_000 + 800 draws total) took 24 seconds.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Got error No model on context stack. trying to find log_likelihood in translation.
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py:102: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb386012810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb388282ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb38a5036d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb38ac51890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb387f9b910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb387ed3350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb387d941d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb388b0fb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb389b25110>]],
#       dtype=object)

# %% [markdown]
# ### Answer:
#
# The plot shows the mean and the 94% HDI for each coefficient.
# And the range for each coefficient is shown on the x-axis.
# According to the numerical result, we can know that those number are sitting inside the range.
# (PS: a warning saying that there is no converge. Perhaps because there are only 400 samples.)
